# %%
import numpy as np

# %%
topoR2 = np.loadtxt('./dihedrals.out')

# %%
topoOURS = np.loadtxt('./dihedrals_new.out')

# %%
for j,i in enumerate(topoR2):
    if not (topoOURS==i).all(1).any():
        print(j, i)

# %%
topoOURS[:,:4].shape
# Out:
# (1360, 4)

# %%
i.shape
# Out:
# (4,)

# %%
i==topoOURS[0,:4]
# Out:
# array([False, False, False, False])

# %%
print(topoOURS[0,:4],topoR2[0,:4])
# Out:
# [16. 15. 17. 19.] [2. 1. 5. 6.]

# %%
np.where()
