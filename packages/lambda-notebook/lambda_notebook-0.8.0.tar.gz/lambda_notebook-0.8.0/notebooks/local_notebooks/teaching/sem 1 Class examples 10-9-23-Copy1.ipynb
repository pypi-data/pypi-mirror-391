# %% [markdown]
# # Class examples from 9/30/25, semantics 1

# %% [markdown]
# Code for tree diagrams illustrating relative clauses and movement.
#
# Note: $i$, $j$ or often used in indexings when the specific value doesn't matter, but only distinctness needs to be notated.

# %%
import svgling, svgling.figure
rctree = ("DP", ("D", "a"), ("NP", ("N", "doctor"),
                             ("CP", ("DP", svgling.core.subscript_node("who", "i")),
                                    ("TP", ("DP", svgling.core.subscript_node("t", "i")),
                                             ("VP", ("V", "likes"), ("DP", "cats"))))))
out = svgling.draw_tree(rctree)
out.movement_arrow((1,1,1,0), (1,1,0))
out.box_constituent((1,1,0))
rctree2 = ("DP", ("D", "a"), ("NP", ("N", "doctor"),
                             ("CP", ("DP", svgling.core.subscript_node("who", "i")),
                                    ("TP", ("DP", "cats"),
                                             ("VP", ("V", "like"), ("DP", svgling.core.subscript_node("t", "i")))))))
out2 = svgling.draw_tree(rctree2)
out2.movement_arrow((1,1,1,1,1), (1,1,0))
out2.box_constituent((1,1,0))
svgling.figure.SideBySide(out, out2)
# Out:
# SideBySide(.., ..)

# %% [markdown]
# ## Relative clause examples

# %%
# %%lamb
# ||Alfonso|| = Alfonso_e
# ||is_|| = L f_<e,t> : f
# ||a|| = L f_<e,t> : f
# ||doctor|| = L x_e : Doctor(x)
# ||likes|| = L y_e : L x_e : Likes(x,y)
# ||cats|| = CATS_e # (not a very complete analysis!)
# Out:
# INFO (core): Coerced guessed type for 'Doctor_t' into <e,t>, to match argument 'x_e'
# INFO (core): Coerced guessed type for 'Likes_t' into <(e,e),t>, to match argument '(x_e, y_e)'
# ⟦Alfonso⟧ = Alfonso_e
# ⟦is_⟧ = (λ f_<e,t>: f_<e,t>)
# ⟦a⟧ = (λ f_<e,t>: f_<e,t>)
# ⟦doctor⟧ = (λ x_e: Doctor_<e,t>(x_e))
# ⟦likes⟧ = (λ y_e: (λ x_e: Likes_<(e,e),t>(x_e, y_e)))
# ⟦cats⟧ = CATS_e

# %%
from lamb.lang import IndexedPronoun, Trace, Binder
himself = lamb.lang.IndexedPronoun.index_factory("himself", tp("e"))
himself(1) # we set aside the presupposition for example purposes
# Out:
# ⟦himself1⟧ = var1_e

# %% [markdown]
# A subject relative clause example:

# %%
rc1 = doctor * (Binder(10, name="who") * (Trace(10) * (likes * cats)))
rc1
# Out:
# 1 composition path.  Result:
#     [0]: ⟦doctor⟧ * ⟦[who10 [t10 [likes cats]]]⟧ leads to: ⟦[doctor [who10 [t10 [likes cats]]]]⟧ = (λ x_e: (Doctor_<e,t>(x_e) & Likes_<(e,e),t>(x_e, CATS_e))) [by PM]

# %%
display(rc1.source_tree())
lamb.display.default(style=lamb.display.DerivStyle.PROOF)
rc1.tree()
# Out:
# Tree('[doctor [who10 [t10 [likes cats]]]]', [Tree('doctor', []), Tree('[who10 [t10 [likes cats]]]', [Tree('who10', []), Tree('[t10 [likes cats]]', [Tree('t10', []), Tree('[likes cats]', [Tree('likes', []), Tree('cats', [])])])])])
# 1 composition path:<br /><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{doctor}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Doctor}({x})$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{who10}}]\!]^{}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>[idx: 10]</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{t}}_{10}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${var10}_{e}$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" ...

# %%
rc2 = doctor * (Binder(10, name="who") * (cats * (likes * Trace(10))))
rc2
# Out:
# 1 composition path.  Result:
#     [0]: ⟦doctor⟧ * ⟦[who10 [cats [likes t10]]]⟧ leads to: ⟦[doctor [who10 [cats [likes t10]]]]⟧ = (λ x_e: (Doctor_<e,t>(x_e) & Likes_<(e,e),t>(CATS_e, x_e))) [by PM]

# %%
display(rc2.source_tree())
rc2.tree()
# Out:
# Tree('[doctor [who10 [cats [likes t10]]]]', [Tree('doctor', []), Tree('[who10 [cats [likes t10]]]', [Tree('who10', []), Tree('[cats [likes t10]]', [Tree('cats', []), Tree('[likes t10]', [Tree('likes', []), Tree('t10', [])])])])])
# 1 composition path:<br /><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{doctor}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Doctor}({x})$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{who10}}]\!]^{}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>[idx: 10]</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{cats}}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${CATS}_{e}$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" al ...

# %%
rc3 = doctor * (Binder(10, name="who") * (Trace(10) * (likes * himself(10))))
rc3
# Out:
# 1 composition path.  Result:
#     [0]: ⟦doctor⟧ * ⟦[who10 [t10 [likes himself10]]]⟧ leads to: ⟦[doctor [who10 [t10 [likes himself10]]]]⟧ = (λ x_e: (Doctor_<e,t>(x_e) & Likes_<(e,e),t>(x_e, x_e))) [by PM]

# %%
display(rc3.source_tree())
rc3.tree()
# Out:
# Tree('[doctor [who10 [t10 [likes himself10]]]]', [Tree('doctor', []), Tree('[who10 [t10 [likes himself10]]]', [Tree('who10', []), Tree('[t10 [likes himself10]]', [Tree('t10', []), Tree('[likes himself10]', [Tree('likes', []), Tree('himself10', [])])])])])
# 1 composition path:<br /><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{doctor}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Doctor}({x})$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{who10}}]\!]^{}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>[idx: 10]</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{t}}_{10}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${var10}_{e}$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" ...

# %%
Alfonso * (doctor * (Binder(10, name="who") * (Trace(10) * (likes * himself(10)))))
# Out:
# 1 composition path.  Result:
#     [0]: ⟦Alfonso⟧ * ⟦[doctor [who10 [t10 [likes himself10]]]]⟧ leads to: ⟦[Alfonso [doctor [who10 [t10 [likes himself10]]]]]⟧ = (Doctor_<e,t>(Alfonso_e) & Likes_<(e,e),t>(Alfonso_e, Alfonso_e)) [by FA]

# %% [markdown]
# **note**: nothing in the system currently prevents there from being an indexing for the reflexive where it is not coindexed with the subject. For the standard approach, we'd need something like Principle A:
#
# * **Principle A**: a [+reflexive] pronoun must be locally bound.
#
# This is a syntactic constraint on LFs. Thought question: can there be a semantic account of principle A effects?

# %%
him = lamb.lang.IndexedPronoun.index_factory("him", tp("e"))
rc3 = doctor * (Binder(10, name="who") * (Trace(10) * (likes * him(11))))
rc3
# Out:
# 1 composition path.  Result:
#     [0]: ⟦doctor⟧ * ⟦[who10 [t10 [likes him11]]]⟧ leads to: ⟦[doctor [who10 [t10 [likes him11]]]]⟧ = (λ x_e: (Doctor_<e,t>(x_e) & Likes_<(e,e),t>(x_e, var11_e))) [by PM]

# %%
display(rc3.source_tree())
rc3.tree()
# Out:
# Tree('[doctor [who10 [t10 [likes him11]]]]', [Tree('doctor', []), Tree('[who10 [t10 [likes him11]]]', [Tree('who10', []), Tree('[t10 [likes him11]]', [Tree('t10', []), Tree('[likes him11]', [Tree('likes', []), Tree('him11', [])])])])])
# 1 composition path:<br /><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{doctor}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Doctor}({x})$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{who10}}]\!]^{}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>[idx: 10]</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{t}}_{10}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${var10}_{e}$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" ...
