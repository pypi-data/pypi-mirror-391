# %%
import nltk # pip install nltk, or conda install nltk
import lamb.auto # unnecessary for running with the lambda notebook kernel, but the lambda notebook package must be installed (`pip install lambda-notebook`)
lamb.display.reset_default()

# %% [markdown]
# ## Ditransitive example
# ### Semantics 1 at JHU, 9/23/2025

# %%
nltk.Tree.fromstring(
    "(S (NP (N Alfonso)) (VP (V' (V introduced) (NP (N Joanna))) (PP (P to) (NP (N Henry)))))")
# Out:
# Tree('S', [Tree('NP', [Tree('N', ['Alfonso'])]), Tree('VP', [Tree("V'", [Tree('V', ['introduced']), Tree('NP', [Tree('N', ['Joanna'])])]), Tree('PP', [Tree('P', ['to']), Tree('NP', [Tree('N', ['Henry'])])])])])

# %%
# %%lamb
# ||Alfonso|| = a
# ||Joanna|| = j
# ||Henry|| = h
# Out:
# ⟦Alfonso⟧ = a_e
# ⟦Joanna⟧ = j_e
# ⟦Henry⟧ = h_e

# %%
# %%lamb
# ||introduce|| = L y_e : L z_e : L x_e: Introduce(x,y,z)
# ||to|| = L x_e : x
# Out:
# INFO (core): Coerced guessed type for 'Introduce_t' into <(e,e,e),t>, to match argument '(x_e, y_e, z_e)'
# ⟦introduce⟧ = (λ y_e: (λ z_e: (λ x_e: Introduce_<(e,e,e),t>(x_e, y_e, z_e))))
# ⟦to⟧ = (λ x_e: x_e)

# %%
nltk.Tree.fromstring("(V' introduced Joanna)")
# Out:
# Tree("V'", ['introduced', 'Joanna'])

# %%
# "bottom-up" composition: use the * operator to compose smaller pieces into bigger pieces
(introduce * Joanna).tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{introduce}}]\!]^{}_{\left\langle{}e,\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} y_{e} \: . \: \lambda{} z_{e} \: . \: \lambda{} x_{e} \: . \: {Introduce}({x}, {y}, {z})$</span></div></div></div></div></div></div><div style="align: center; vertical-align: middle; display: table-cell;"><span style="padding:1px;">*</span></div><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{Joanna}}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${j}_{e}$</span></div></div></div></div></div></div></div></div><div style="display:table-cell;vertical-align:middle;border-left:1px solid #848482;padding:0.5em"><div style="white-space:nowrap; color:blue;"><b>[<span>FA</span>]</b></div></div></div><div align="center" style="display:table-row;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table-cell;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{[introduce Joanna]}}]\!]^{}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} z_{e} \: . \: \lambda{} x_{e} \: . \: {Introduce}({x}, {j}_{e}, {z})$</span></div></div></div></div></div></div><div style="display:table-cell;"></div></div></div><br /><br />

# %%
nltk.Tree.fromstring("(PP to Henry)")
# Out:
# Tree('PP', ['to', 'Henry'])

# %%
(to * Henry).tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{to}}]\!]^{}_{\left\langle{}e,e\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {x}$</span></div></div></div></div></div></div><div style="align: center; vertical-align: middle; display: table-cell;"><span style="padding:1px;">*</span></div><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{Henry}}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${h}_{e}$</span></div></div></div></div></div></div></div></div><div style="display:table-cell;vertical-align:middle;border-left:1px solid #848482;padding:0.5em"><div style="white-space:nowrap; color:blue;"><b>[<span>FA</span>]</b></div></div></div><div align="center" style="display:table-row;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table-cell;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{[to Henry]}}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${h}_{e}$</span></div></div></div></div></div></div><div style="display:table-cell;"></div></div></div><br /><br />

# %%
nltk.Tree.fromstring("(VP (V' introduce Joanna) (PP to Henry))")
# Out:
# Tree('VP', [Tree("V'", ['introduce', 'Joanna']), Tree('PP', ['to', 'Henry'])])

# %%
((introduce * Joanna) * (to * Henry)).tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{introduce}}]\!]^{}_{\left\langle{}e,\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} y_{e} \: . \: \lambda{} z_{e} \: . \: \lambda{} x_{e} \: . \: {Introduce}({x}, {y}, {z})$</span></div></div></div></div></div></div><div style="align: center; vertical-align: middle; display: table-cell;"><span style="padding:1px;">*</span></div><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{Joanna}}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${j}_{e}$</span></div></div></div></div></div></div></div></div><div style="display:table-cell;vertical-align:middle;border-left:1px solid #848482;padding:0.5em"><div style="white-space:nowrap; color:blue;"><b>[<span>FA</span>]</b></div></div></div><div align="center" style="display:table-row;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table-cell;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{[introduce Joanna]}}]\!]^{}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} z_{e} \: . \: \lambda{} x_{e} \: . \: {Introduce}({x}, {j}_{e}, {z})$</span></div></div></div></div></div></div><div style="display:table-cell;"></div></div></div></div><div style="align: center; vertical-align: middle; display: table-cell;"><span style="padding:1px;">*</span></div><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:t ...

# %%
(Alfonso * ((introduce * Joanna) * (to * Henry))).tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{Alfonso}}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${a}_{e}$</span></div></div></div></div></div></div><div style="align: center; vertical-align: middle; display: table-cell;"><span style="padding:1px;">*</span></div><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{introduce}}]\!]^{}_{\left\langle{}e,\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} y_{e} \: . \: \lambda{} z_{e} \: . \: \lambda{} x_{e} \: . \: {Introduce}({x}, {y}, {z})$</span></div></div></div></div></div></div><div style="align: center; vertical-align: middle; display: table-cell;"><span style="padding:1px;">*</span></div><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{Joanna}}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${j}_{e}$</span></div></div></div></div></div></div></div></div><div style="display:table-cell;vertical-align:middle;border-left:1px solid #848482;padding:0.5em"><div style="white-space:nowrap; color:blue;"><b>[<span>FA</span>]</b></div></div></div><div align="center" style="display:table-row;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px; ...

# %%
lamb.display.default(style=lamb.display.DerivStyle.TREE)
(Alfonso * ((introduce * Joanna) * (to * Henry))).tree()
# Out:
# 1 composition path:<br /><div style="display:inline-grid;grid-template-columns: repeat(2, auto);align-items:start;border:none;font-family: times, serif; font-weight: normal; font-style: normal; font-size: 16px;"><div style="grid-row:1;grid-column:1;justify-self:right;width:0;"><div style="display:grid;grid-template-columns:auto auto;float:right;transform:translate(50%);white-space:nowrap;"><div style="align-self:end;justify-self:right;"><div style="white-space:nowrap; color:blue;padding-right:4px;"><b>[<span>FA</span>]</b></div></div><div style="justify-self:left;"><div align="center" style="display:block;padding-left:0.5em;padding-right:0.5em;"><div style="display:inline-block;"><span>${Introduce}({a}_{e}, {j}_{e}, {h}_{e})$</span></div></div></div></div></div><div style="grid-row:1;grid-column:1/3;justify-self:center;height:0;overflow:hidden;padding-right:1em;padding-left:1em;"><div style="display:grid;grid-template-columns:auto auto;"><div style="align-self:end;justify-self:right;"><div style="white-space:nowrap; color:blue;padding-right:4px;"><b>[<span>FA</span>]</b></div></div><div style="justify-self:left;"><div align="center" style="display:block;padding-left:0.5em;padding-right:0.5em;"><div style="display:inline-block;"><span>${Introduce}({a}_{e}, {j}_{e}, {h}_{e})$</span></div></div></div></div></div><div style="grid-column:1;grid-row:2;justify-self:right;"><div style="display:inline-grid;grid-template-columns: 1fr;align-items:start;border:none;"><div style="grid-column:1;grid-row:1;height:32px;" align="center"><svg baseProfile="tiny" height="0" width="0" preserveAspectRatio="none" version="1.2" viewBox="0,0,100,100" xmlns="http://www.w3.org/2000/svg" style="height:100%;width:100%;display:block;" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs></defs><line stroke="black" x1="100" x2="50" y1="2" y2="98" stroke_width="1px" vector-effect="non-scaling-stroke"></line></svg></div><div style="grid-column:1;grid-row:2;justify-self:center;"><div align="center" style="display:block;padding-left:1em;padding-right:1em;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{Alfonso}}]\!]^{}_{e}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>${a}_{e}$</span></div></div></div></div></div></div></div></div><div style="grid-column:2;grid-row:2;"><div style="display:inline-grid;grid-template-columns: repeat(2, auto);align-items:start;border:none;"><div style="grid-column:1;grid-row:1;height:32px;"><svg baseProfile="tiny" height="0" width="0" preserveAspectRatio="none" version="1.2" viewBox="0,0,100,100" xmlns="http://www.w3.org/2000/svg" style="height:100%;width:100%;display:block;" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs></defs><line stroke="black" x1="0" x2="100" y1="2" y2="98" stroke_width="1px" vector-effect="non-scaling-stroke"></line></svg></div><div style="grid-row:2;grid-column:1;justify-self:right;width:0;"><div style="display:grid;grid-template-columns:auto auto;float:right;transform:translate(50%);white-space:nowrap;"><div style="align-self:end;justify-self:right;"><div style="white-space:nowrap; color:blue;padding-right:4px;"><b>[<span>FA</span>]</b></div></div><div style="justify-self:left;"><div align="center" style="display:block;padding-left:0.5em;padding-right:0.5em;"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Introduce}({x}, {j}_{e}, {h}_{e})$</span></div></div></div></div></div><div style="grid-row:2;grid-column:1/3;justify-self:center;height:0;overflow:hidden;padding-right:1em;padding-left:1em;"><div style="display:grid;grid-template-columns:auto a ...

# %% [markdown]
# ## Repeated PM example

# %%
# %%lamb
# ||small|| = L x_e : Small(x)
# ||gray|| = L x_e : Gray(x)
# ||spotted|| = L x_e : Spotted(x)
# ||cat|| = L x_e : Cat(x)
# Out:
# INFO (core): Coerced guessed type for 'Small_t' into <e,t>, to match argument 'x_e'
# INFO (core): Coerced guessed type for 'Gray_t' into <e,t>, to match argument 'x_e'
# INFO (core): Coerced guessed type for 'Spotted_t' into <e,t>, to match argument 'x_e'
# INFO (core): Coerced guessed type for 'Cat_t' into <e,t>, to match argument 'x_e'
# ⟦small⟧ = (λ x_e: Small_<e,t>(x_e))
# ⟦gray⟧ = (λ x_e: Gray_<e,t>(x_e))
# ⟦spotted⟧ = (λ x_e: Spotted_<e,t>(x_e))
# ⟦cat⟧ = (λ x_e: Cat_<e,t>(x_e))

# %%
spotted * cat
# Out:
# 1 composition path.  Result:
#     [0]: ⟦spotted⟧ * ⟦cat⟧ leads to: ⟦[spotted cat]⟧ = (λ x_e: (Cat_<e,t>(x_e) & Spotted_<e,t>(x_e))) [by PM]

# %%
(spotted * cat)[0].content.derivation
# Out:
#  1. (λ f_<e,t>: (λ g_<e,t>: (λ x_e: (f_<e,t>(x_e) & g_<e,t>(x_e)))))(λ x_e: Spotted_<e,t>(x_e))(λ x_e: Cat_<e,t>(x_e))    (recursive reduction of subexpression 0)
#  2. (λ g_<e,t>: (λ x_e: (Spotted_<e,t>(x_e) & g_<e,t>(x_e))))(λ x_e: Cat_<e,t>(x_e))    (Reduction)
#  3. (λ x_e: (Spotted_<e,t>(x_e) & (λ x_e: Cat_<e,t>(x_e))(x_e)))    ([[Reduction]])
#  4. (λ x_e: (Spotted_<e,t>(x_e) & Cat_<e,t>(x_e)))    (Recursive simplification of body)
#  5. (λ x_e: (Cat_<e,t>(x_e) & Spotted_<e,t>(x_e)))

# %%
(spotted * cat).tree()
# Out:
# 1 composition path:<br /><div style="display:inline-grid;grid-template-columns: repeat(2, auto);align-items:start;border:none;font-family: times, serif; font-weight: normal; font-style: normal; font-size: 16px;"><div style="grid-row:1;grid-column:1;justify-self:right;width:0;"><div style="display:grid;grid-template-columns:auto auto;float:right;transform:translate(50%);white-space:nowrap;"><div style="align-self:end;justify-self:right;"><div style="white-space:nowrap; color:blue;padding-right:4px;"><b>[<span>PM</span>]</b></div></div><div style="justify-self:left;"><div align="center" style="display:block;padding-left:0.5em;padding-right:0.5em;"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Cat}({x}) \wedge{} {Spotted}({x})$</span></div></div></div></div></div><div style="grid-row:1;grid-column:1/3;justify-self:center;height:0;overflow:hidden;padding-right:1em;padding-left:1em;"><div style="display:grid;grid-template-columns:auto auto;"><div style="align-self:end;justify-self:right;"><div style="white-space:nowrap; color:blue;padding-right:4px;"><b>[<span>PM</span>]</b></div></div><div style="justify-self:left;"><div align="center" style="display:block;padding-left:0.5em;padding-right:0.5em;"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Cat}({x}) \wedge{} {Spotted}({x})$</span></div></div></div></div></div><div style="grid-column:1;grid-row:2;justify-self:right;"><div style="display:inline-grid;grid-template-columns: 1fr;align-items:start;border:none;"><div style="grid-column:1;grid-row:1;height:32px;" align="center"><svg baseProfile="tiny" height="0" width="0" preserveAspectRatio="none" version="1.2" viewBox="0,0,100,100" xmlns="http://www.w3.org/2000/svg" style="height:100%;width:100%;display:block;" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs></defs><line stroke="black" x1="100" x2="50" y1="2" y2="98" stroke_width="1px" vector-effect="non-scaling-stroke"></line></svg></div><div style="grid-column:1;grid-row:2;justify-self:center;"><div align="center" style="display:block;padding-left:1em;padding-right:1em;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{spotted}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Spotted}({x})$</span></div></div></div></div></div></div></div></div><div style="grid-column:2;grid-row:2;"><div style="display:inline-grid;grid-template-columns: 1fr;align-items:start;border:none;"><div style="grid-column:1;grid-row:1;height:32px;" align="center"><svg baseProfile="tiny" height="0" width="0" preserveAspectRatio="none" version="1.2" viewBox="0,0,100,100" xmlns="http://www.w3.org/2000/svg" style="height:100%;width:100%;display:block;" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs></defs><line stroke="black" x1="0" x2="50" y1="2" y2="98" stroke_width="1px" vector-effect="non-scaling-stroke"></line></svg></div><div style="grid-column:1;grid-row:2;justify-self:center;"><div align="center" style="display:block;padding-left:1em;padding-right:1em;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{cat}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{}  ...

# %%
(small * (gray * (spotted * cat)))
# Out:
# 1 composition path.  Result:
#     [0]: ⟦small⟧ * ⟦[gray [spotted cat]]⟧ leads to: ⟦[small [gray [spotted cat]]]⟧ = (λ x_e: (((Cat_<e,t>(x_e) & Gray_<e,t>(x_e)) & Small_<e,t>(x_e)) & Spotted_<e,t>(x_e))) [by PM]

# %%
# lamb.display.reset_default()
lamb.display.default(style=lamb.display.DerivStyle.PROOF)
(small * (gray * (spotted * cat))).tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{small}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Small}({x})$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{gray}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Gray}({x})$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table;"><div align="center" style="display:table-row;"><div style="display:table-cell;table-layout:auto;vertical-align:bottom;border-bottom:1px solid #848482;"><div style="display: table;"><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{spotted}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Spotted}({x})$</span></div></div></div></div></div></div><div style="display: table-cell; padding-left:4em;"></div><div style="vertical-align:bottom;display:table-cell;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{cat}}]\!]^{}_{\left\langle{}e,t\right\ ...

# %%
lamb.display.default(style=lamb.display.DerivStyle.TREE) # (note: small rendering issue with this)
(small * (gray * (spotted * cat))).tree()
# Out:
# 1 composition path:<br /><div style="display:inline-grid;grid-template-columns: repeat(2, auto);align-items:start;border:none;font-family: times, serif; font-weight: normal; font-style: normal; font-size: 16px;"><div style="grid-row:1;grid-column:1;justify-self:right;width:0;"><div style="display:grid;grid-template-columns:auto auto;float:right;transform:translate(50%);white-space:nowrap;"><div style="align-self:end;justify-self:right;"><div style="white-space:nowrap; color:blue;padding-right:4px;"><b>[<span>PM</span>]</b></div></div><div style="justify-self:left;"><div align="center" style="display:block;padding-left:0.5em;padding-right:0.5em;"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Cat}({x}) \wedge{} {Gray}({x}) \wedge{} {Small}({x}) \wedge{} {Spotted}({x})$</span></div></div></div></div></div><div style="grid-row:1;grid-column:1/3;justify-self:center;height:0;overflow:hidden;padding-right:1em;padding-left:1em;"><div style="display:grid;grid-template-columns:auto auto;"><div style="align-self:end;justify-self:right;"><div style="white-space:nowrap; color:blue;padding-right:4px;"><b>[<span>PM</span>]</b></div></div><div style="justify-self:left;"><div align="center" style="display:block;padding-left:0.5em;padding-right:0.5em;"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Cat}({x}) \wedge{} {Gray}({x}) \wedge{} {Small}({x}) \wedge{} {Spotted}({x})$</span></div></div></div></div></div><div style="grid-column:1;grid-row:2;justify-self:right;"><div style="display:inline-grid;grid-template-columns: 1fr;align-items:start;border:none;"><div style="grid-column:1;grid-row:1;height:32px;" align="center"><svg baseProfile="tiny" height="0" width="0" preserveAspectRatio="none" version="1.2" viewBox="0,0,100,100" xmlns="http://www.w3.org/2000/svg" style="height:100%;width:100%;display:block;" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs></defs><line stroke="black" x1="100" x2="50" y1="2" y2="98" stroke_width="1px" vector-effect="non-scaling-stroke"></line></svg></div><div style="grid-column:1;grid-row:2;justify-self:center;"><div align="center" style="display:block;padding-left:1em;padding-right:1em;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\text{\textbf{small}}]\!]^{}_{\left\langle{}e,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Small}({x})$</span></div></div></div></div></div></div></div></div><div style="grid-column:2;grid-row:2;"><div style="display:inline-grid;grid-template-columns: repeat(2, auto);align-items:start;border:none;"><div style="grid-column:1;grid-row:1;height:32px;"><svg baseProfile="tiny" height="0" width="0" preserveAspectRatio="none" version="1.2" viewBox="0,0,100,100" xmlns="http://www.w3.org/2000/svg" style="height:100%;width:100%;display:block;" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs></defs><line stroke="black" x1="0" x2="100" y1="2" y2="98" stroke_width="1px" vector-effect="non-scaling-stroke"></line></svg></div><div style="grid-row:2;grid-column:1;justify-self:right;width:0;"><div style="display:grid;grid-template-columns:auto auto;float:right;transform:translate(50%);white-space:nowrap;"><div style="align-self:end;justify-self:right;"><div style="white-space:nowrap; color:blue;padding-right:4px;"><b>[<span>PM</span>]</b></div></div><div style="justify-self:left;"><div align="center" style="display:block;padding-left:0.5em;padding-right:0.5em;"><div style="display:inline-block;"><span>$\lambda{} x_{e} \: . \: {Cat}({x}) \wedge{} {Gray}({x}) \wedge{} {Spotted}({x})$</span ...
