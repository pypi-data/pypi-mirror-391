# %%
import numpy as np
from plotfig import plot_one_group_bar_figure

np.random.seed(0)
data1 = np.random.rand(10)
data2 = np.random.rand(10)

plot_one_group_bar_figure([data1, data2], show_dots=True)
# Out:
# [ 0.03047171 -0.10399841  0.07504512  0.09405647 -0.19510352 -0.13021795
#   0.01278404 -0.03162426 -0.00168012 -0.08530439]
# [1.03047171 0.89600159 1.07504512 1.09405647 0.80489648 0.86978205
#  1.01278404 0.96837574 0.99831988 0.91469561]
# <Axes: >

# %%
import numpy as np
from plotfig import plot_one_group_bar_figure

np.random.seed(1998)
data1 = np.random.rand(10)
data2 = np.random.rand(10)

plot_one_group_bar_figure([data1, data2], show_dots=False)
# Out:
# [ 0.03047171 -0.10399841  0.07504512  0.09405647 -0.19510352 -0.13021795
#   0.01278404 -0.03162426 -0.00168012 -0.08530439]
# [1.03047171 0.89600159 1.07504512 1.09405647 0.80489648 0.86978205
#  1.01278404 0.96837574 0.99831988 0.91469561]
# <Axes: >
