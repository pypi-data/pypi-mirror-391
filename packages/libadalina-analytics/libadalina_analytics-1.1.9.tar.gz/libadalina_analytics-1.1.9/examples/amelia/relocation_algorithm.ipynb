# %% [markdown]
# # Relocation algorithm

# %% [markdown]
# Install libadalina-analytics using `pip`

# %%
pip install libadalina-analytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: libadalina-analytics in ./.local/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: libadalina-core==1.2.0 in ./.local/lib/python3.10/site-packages (from libadalina-analytics) (1.2.0)
# Requirement already satisfied: highspy==1.11.0 in ./.local/lib/python3.10/site-packages (from libadalina-analytics) (1.11.0)
# Requirement already satisfied: networkx==3.4.2 in ./.local/lib/python3.10/site-packages (from libadalina-analytics) (3.4.2)
# Requirement already satisfied: pydantic==2.10.6 in ./.local/lib/python3.10/site-packages (from libadalina-analytics) (2.10.6)
# Requirement already satisfied: scikit-learn==1.7.0 in ./.local/lib/python3.10/site-packages (from libadalina-analytics) (1.7.0)
# Requirement already satisfied: numpy in /opt/tljh/user/lib/python3.10/site-packages (from highspy==1.11.0->libadalina-analytics) (1.26.4)
# Requirement already satisfied: apache-sedona==1.7.1 in ./.local/lib/python3.10/site-packages (from apache-sedona[spark]==1.7.1->libadalina-core==1.2.0->libadalina-analytics) (1.7.1)
# Requirement already satisfied: pyspark==3.3.2 in ./.local/lib/python3.10/site-packages (from libadalina-core==1.2.0->libadalina-analytics) (3.3.2)
# Requirement already satisfied: pandas==2.2.3 in ./.local/lib/python3.10/site-packages (from libadalina-core==1.2.0->libadalina-analytics) (2.2.3)
# Requirement already satisfied: geopandas==1.0.1 in ./.local/lib/python3.10/site-packages (from libadalina-core==1.2.0->libadalina-analytics) (1.0.1)
# Requirement already satisfied: shapely==2.1.1 in ./.local/lib/python3.10/site-packages (from libadalina-core==1.2.0->libadalina-analytics) (2.1.1)
# Requirement already satisfied: install-jdk==1.1.0 in ./.local/lib/python3.10/site-packages (from libadalina-core==1.2.0->libadalina-analytics) (1.1.0)
# Requirement already satisfied: click==8.2.1 in ./.local/lib/python3.10/site-packages (from libadalina-core==1.2.0->libadalina-analytics) (8.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.local/lib/python3.10/site-packages (from pydantic==2.10.6->libadalina-analytics) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./.local/lib/python3.10/site-packages (from pydantic==2.10.6->libadalina-analytics) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./.local/lib/python3.10/site-packages (from pydantic==2.10.6->libadalina-analytics) (4.15.0)
# Requirement already satisfied: scipy>=1.8.0 in /opt/tljh/user/lib/python3.10/site-packages (from scikit-learn==1.7.0->libadalina-analytics) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/tljh/user/lib/python3.10/site-packages (from scikit-learn==1.7.0->libadalina-analytics) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/tljh/user/lib/python3.10/site-packages (from scikit-learn==1.7.0->libadalina-analytics) (3.5.0)
# Requirement already satisfied: attrs in /opt/tljh/user/lib/python3.10/site-packages (from apache-sedona==1.7.1->apache-sedona[spark]==1.7.1->libadalina-core==1.2.0->libadalina-analytics) (23.2.0)
# Requirement already satisfied: pyogrio>=0.7.2 in ./.local/lib/python3.10/site-packages (from geopandas==1.0.1->libadalina-core==1.2.0->libadalina-analytics) (0.10.0)
# Requirement already satisfied: packaging in /opt/tljh/user/lib/python3.10/site-packages (from geopandas==1.0.1->libadalina-core==1.2.0->libadalina-analytics) (23.2)
# Requirement already satisfied: pyproj>=3.3.0 in ./.local/lib/python3.10/site-packages (from geopandas==1.0.1->libadalina-core==1.2.0->libadalina-analytics) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.10/site-packages (from pandas==2.2.3->libadalina-core==1.2.0->libadalina-analytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/tljh/user/lib/python3.10/site-packages (from pandas==2.2.3->libadalina-core==1.2.0->libadalina-analytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/tljh/user/lib/python3.10/site-packages (from pandas==2.2.3->libadalina-core==1.2.0->libadalina-analytics) (2024.1)
# Requirement already satisfied: py4j==0.10.9.5 in ./.local/lib/python3.10/site-packages (from pyspark==3.3.2->libadalina-core==1.2.0->libadalina-analytics) (0.10.9.5)
# Requirement already satisfied: certifi in /opt/tljh/user/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas==1.0.1->libadalina-core==1.2.0->libadalina-analytics) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->libadalina-core==1.2.0->libadalina-analytics) (1.16.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import the Amelia toolkit to read datasets.

# %%
from ameliadp_sql_toolkit import GrinsAmeliaSQLToolkit 
amelia_sql_toolkit = GrinsAmeliaSQLToolkit()

# %% [markdown]
# Read the input dataset containing all the data for the relocation problem

# %%
relocation_df = amelia_sql_toolkit.read_data(table_name='parabiago_unsat_epsg32632_wkt_amelia')
# Out:
# Digit your password here:  ········

# %% [markdown]
# The input dataset consists of two merged datasets:
#
# 1. **Area Population Data**: contains information about geographical areas and their population counts
#
# 2. **Facilities Data**: contains locations of facilities (hospitals) and their available resources (beds, personnel)
#
# These two datasets are merged into a single dataframe.

# %%
relocation_df[relocation_df['popolazion'].notna()].head()
# Out:
#                 id  popolazion  \
# 0  CUSANO MILANINO      189.12
# 1        ALBIZZATE       51.35
# 2           CESATE      143.09
# 3   CERRO MAGGIORE      150.31
# 4   CESANO MADERNO      395.49
#
#                                             geometry  usable  beds  personnel  \
# 0  POLYGON ((515162.653766 5045374.60466, 515207....     NaN   NaN        NaN
# 1  POLYGON ((484862.09332 5065331.546162, 484862....     NaN   NaN        NaN
# 2  POLYGON ((504759.273301 5050484.89305, 504759....     NaN   NaN        NaN
# 3  POLYGON ((495239.306843 5050834.835681, 495258...     NaN   NaN        NaN
# 4  POLYGON ((508683.495302 5054098.191944, 508683...     NaN   NaN        NaN
#
#    metadata_vd                metadata_vtd metadata_ud
# 0            1  2025-08-31 15:43:36.519843  2025-08-31
# 1            1  2025-08-31 15:43:36.519843  2025-08-31
# 2            1  2025-08-31 15:43:36.519843  2025-08-31
# 3            1  2025-08-31 15:43:36.519843  2025-08-31
# 4            1  2025-08-31 15:43:36.519843  2025-08-31

# %%
relocation_df[relocation_df['personnel'].notna()].head()
# Out:
#                                                 id  popolazion  \
# 175  IRCCS IST. SCIENTIFICO DI RIABILITAZIONE - MI         NaN
# 176             POLICLINICO SAN MARCO - OSIO SOTTO         NaN
# 177              PRESIDIO OSPEDALIERO GARDONE V.T.         NaN
# 178                     OSPEDALE CIVILE DI LEGNANO         NaN
# 179                 IST. CLIN. HUMANITAS - ROZZANO         NaN
#
#                                         geometry  usable   beds  personnel  \
# 175  POINT (520498.9153106844 5032321.101216923)     1.0   80.0       16.0
# 176  POINT (546112.3899832936 5050195.388898186)     1.0  297.0       60.0
# 177  POINT (592159.6966155188 5058759.244051828)     1.0  109.0       22.0
# 178  POINT (491210.4726045889 5047456.290382859)     1.0  481.0       97.0
# 179  POINT (513109.4762980791 5024346.926455218)     1.0  754.0      151.0
#
#      metadata_vd                metadata_vtd metadata_ud
# 175            1  2025-08-31 15:43:36.519843  2025-08-31
# 176            1  2025-08-31 15:43:36.519843  2025-08-31
# 177            1  2025-08-31 15:43:36.519843  2025-08-31
# 178            1  2025-08-31 15:43:36.519843  2025-08-31
# 179            1  2025-08-31 15:43:36.519843  2025-08-31

# %% [markdown]
# The relocation algorithm is executed on the dataset using two types of resources with specific requirements per demand unit:
#
# * **Beds**: one bed is required to serve each unit of demand
# * **Personnel**: 0.2 personnel units are needed per unit of demand (1 staff member can serve 5 demand units)
#
# The algorithm will:
# - Match demand (population) with available facility resources
# - Consider both bed capacity and personnel constraints
# - Optimize the allocation while minimizing transportation costs

# %%
from libadalina_core.sedona_utils import EPSGFormats
from libadalina_analytics.relocation.algorithms import relocation_algorithm
from libadalina_analytics.relocation.models import RelocationResource

relocation_solution = relocation_algorithm(
    relocation_df,
    epsg=EPSGFormats.EPSG32632,
    id_column='id',
    demand_column='popolazion',
    resources=[
        RelocationResource(column_name='beds', amount=1.0),
        RelocationResource(column_name='personnel', amount=0.2)
    ]
)
# Out:
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 66055 rows; 97015 cols; 354955 nonzeros; 180 integer variables (180 binary)
# Coefficient ranges:
#   Matrix [1e+00, 4e+04]
#   Cost   [6e+00, 2e+03]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+00]
# Presolving model
# 895 rows, 96475 cols, 224275 nonzeros  0s
# 895 rows, 96475 cols, 224275 nonzeros  0s
#
# Solving MIP model with:
#    895 rows
#    96475 cols (0 binary, 0 integer, 0 implied int., 96475 continuous, 0 domain fixed)
#    224275 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            12998.02           Large        0      0      0         0     1.2s
#  T       0       0         0   0.00%   0               1428.95          100.00%        0      0      0      8154    10.5s
#          1       0         1 100.00%   1428.95         1428.95            0.00%        0      0      0      8154    10.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      1428.95
#   Dual bound        1428.95
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      9.2575802803
#   Solution status   feasible
#                     1428.95 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            10.49 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     8154 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# MIP  has 66236 rows; 97016 cols; 420110 nonzeros; 180 integer variables (180 binary)
# Coefficient ranges:
#   Matrix [1e+00, 4e+04]
#   Cost   [1e+00, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+03]
# Presolving model
# 1076 rows, 96476 cols, 289430 nonzeros  0s
# 1076 rows, 96476 cols, 289430 nonzeros  0s
#
# Solving MIP model with:
#    1076 rows
#    96476 cols (0 binary, 0 integer, 0 implied int., 96476 continuous, 0 domain fixed)
#    289430 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   0               inf                  inf        0      0      0         0     1.6s
#  T       0       0         0   0.00%   0               0.9982007739     100.00%        0      0      0      2625     3.6s
#          1       0         1 100.00%   0.9982007739    0.9982007739       0.00%        0      0      0      2625     3.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      0.998200773914
#   Dual bound        0.998200773914
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      9.48905944824e-05
#   Solution status   feasible
#                     0.998200773914 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            3.57 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2625 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# MIP  has 66236 rows; 97016 cols; 420110 nonzeros; 180 integer variables (180 binary)
# Coefficient ranges:
#   Matrix [1e+00, 4e+04]
#   Cost   [1e+01, 3e+05]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+03]
# Presolving model
# 1076 rows, 96475 cols, 289250 nonzeros  0s
# 1076 rows, 96475 cols, 289250 nonzeros  0s
#
# Solving MIP model with:
#    1076 rows
#    96475 cols (0 binary, 0 integer, 0 implied int., 96475 continuous, 0 domain fixed)
#    289250 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   0               inf                  inf        0      0      0         0     1.5s
#  T       0       0         0   0.00%   0               985030.001301    100.00%        0      0      0      5501     3.1s
#          1       0         1 100.00%   985030.001301   985030.001301      0.00%        0      0      0      5501     3.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      985030.001301
#   Dual bound        985030.001301
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      9.60826873779e-05
#   Solution status   feasible
#                     985030.001301 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            3.13 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     5501 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# MIP  has 66237 rows; 97016 cols; 451557 nonzeros; 180 integer variables (180 binary)
# Coefficient ranges:
#   Matrix [1e+00, 3e+05]
#   Cost   [1e-01, 2e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+06]
# Presolving model
# 1077 rows, 96475 cols, 320697 nonzeros  0s
# 1077 rows, 96475 cols, 320697 nonzeros  0s
#
# Solving MIP model with:
#    1077 rows
#    96475 cols (0 binary, 0 integer, 0 implied int., 96475 continuous, 0 domain fixed)
#    320697 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   0               inf                  inf        0      0      0         0     1.7s
#  T       0       0         0   0.00%   0               0.986266457      100.00%        0      0      0      4286     3.5s
#          1       0         1 100.00%   0.986266457     0.986266457        0.00%        0      0      0      4286     3.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      0.986266456991
#   Dual bound        0.986266456991
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.0119035243988
#   Solution status   feasible
#                     0.986266456991 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            3.48 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     4286 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)

# %% [markdown]
# The relocation algorithm outputs a new DataFrame containing:
# * Unserved population for each area
# * Transportation costs
# * Cost penalties for unserved demand

# %%
relocation_solution.head()
# Out:
#               area  demand                                           geometry  \
# 0  CUSANO MILANINO  189.12  POLYGON ((515162.653766 5045374.60466, 515207....
# 1        ALBIZZATE   51.35  POLYGON ((484862.09332 5065331.546162, 484862....
# 2           CESATE  143.09  POLYGON ((504759.273301 5050484.89305, 504759....
# 3   CERRO MAGGIORE  150.31  POLYGON ((495239.306843 5050834.835681, 495258...
# 4   CESANO MADERNO  395.49  POLYGON ((508683.495302 5054098.191944, 508683...
#
#    unserved  unserved_fract  cost_transport  cost_unserved
# 0       0.0             0.0     2610.289095            0.0
# 1       0.0             0.0      435.942921            0.0
# 2       0.0             0.0     5744.942451            0.0
# 3       0.0             0.0     1014.808312            0.0
# 4       0.0             0.0    12942.243358            0.0
